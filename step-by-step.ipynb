# %% [markdown]
# # 1. 개요
#
# 이 문서는 인터넷 상에 공개된 ```한국잡월드```의 파편화된 복리후생 규정 파일을 구조적으로 정규화하고 내용을 표준화하는 것을 목표로 합니다.
# > (참고)<br>
# > 이 문서에서는 ```정규화```와 ```표준화```를 거의 같은 의미로 사용하고 있습니다.<br>
# > 굳으 나누자면 ```정규화```는 문서의 구조를 통일시키는 것을 의미하며, ```표준화```는 문서의 내용을 통일시키는 것을 의미하지만 혼용하여 사용하고 있습니다.
#
# 작업에 사용된 파일은 ```한국잡월드의 복리후생```에 대해 인터넷 검색을 통해 생성되었습니다. 총 5개의 파일로 이루어져 있으며, 전반적으로 유사한 내용을 전달하고 있습니다.
# 각 문서의 특징, 요구 사항, 제한 사항은 아래와 같습니다.
#
# ## 1.1. 문서의 특징
# 1. 형태1 : 원본 형태로 아주 잘 쓰여져있는 문서
# 2. 형태2 : 형태1과 유사하며, 전체적으로 재작성된 문서
# 3. 형태3 : 형태1과 제목은 유사하나, 내용이 조금씩 빠져있는 문서
# 4. 형태4 : 형태1과 유사해보이지만, 아주 형편없고 내용이 많이 빠진 문서
# 5. 형태5 : 제목의 순서, 형태가 완전히 다르며, 불필요한 내용이 추가된 문서
#
# ## 1.2. 요구 사항
# 1. 형태 1 ~ 5의 구조적 혹은 내용적인 특징을 잘 담고 있는 표준 문서의 생성이 필요함
# 2. 즉, 생성된 표준문서는,
#     * 형태 1 ~ 5의 구조적 특징을 담고 있으며, 중요한 내용은 빠짐없이 모두 포함되어야 합니다.
#     * 소수의 문서에서만 등장하는 불필요한 내용은 포함되지 않아야 하며, 다수에 많이 등장하는 내용을 기반으로 합니다.
#
# ## 1.3. 추가 요구 사항 (제공되면 더 좋지만, 필수는 아님)
# * 제공할 문서의 내용 중 숫자와 같은 변경 가능한 기준은 'blank'로 제공하여, 필요하다면 'blank'를 채워서 사용하도록 가이드 하면 좋습니다.
#
# ## 1.4. 제한사항
# * 문서는 손으로 편집해서 사용할 수 없습니다.
# * 현재는 복리후생이 과업이지만, 더 넓은 과업 영역 (계약 정보, 월급 정보 등..)으로 적용될 수 있는 형태가 필요합니다.

# %% [markdown]
# # 2. 실행 방법, 처리 흐름 및 사용 기술
# 파이썬 3.11 환경에서 ```requirements.txt```에 명시된 라이브러리를 기반으로 개발되었습니다.
#
# ## 2.1. 실행 방법
# 1. ```requirements.txt```에 명시된 의존성 라이브러리를 설치합니다.<br>
# (참고) 파이썬 가상환경을 구성한 후, 라이브러리를 설치하는 것을 권장합니다.<br>
#     ```bash
#     pip install -r requirements.txt
#     ```
#
# 2. (Optional) 가상 환경에서 실행 시<br>
# (참고) 가상 환경이 ```.venv```에 구성되었음을 가정<br>
#     ```bash
#     source .venv/bin/activate
#     ```
#
# 3. 실행<br>
#     ```bash
#     python main.py
#     ```
#
# ## 2.2. 처리 흐름
# ```main.py``` 파일에서는 아래와 같은 흐름으로 과업을 처리합니다.
#
# > (참고)<br>
# > 아래에 기술된 흐름은 이 파일의 아래 ```3. 단계별 실행```에도 구성되어 있어 직접 실행해 볼 수 있습니다.
#
# 1. 의존성 라이브러리 임포트
# 2. Bedrock 클라이언트 Instantiation
# 3. Document Manager Instantiation
# 4. 정규화된 문서 구조 생성
# 5. 정규화된 문서 구조에서 헤더 식별
# 6. 식별된 헤더를 기준으로 문서 내용 정규화
# 7. 완료되면 기본적으로 아래와 같이 두개의 파일이 생성됨
#     * ```한국잡월드_복리후생_문서구조.md```: 정규화된 문서 구조
#     * ```한국잡월드_복리후생_표준파일_리랭커미사용.md```: 정규화된 문서 내용 (기본적으로 ```Reranker``` 미사용)
#
# ## 2.3. 사용 기술
# 아래 ```LLM Tech Stack``` 이미지의 아래부터 사용된 기술을 나열하면 아래와 같습니다.<br>
# ![](./images/llm-tech-stack-1400.png)<br>
#
# 1. 모델 (via ```Amazon Bedrock```)
#     * 정규화: ```Anthropic Claude-3 Sonnet``` (```anthropic.claude-3-sonnet-20240229-v1:0```)
#     * 임베딩: ```Amazon Titan Embedding Text v2``` (```amazon.titan-embed-text-v2:0```)
# 2. 벡터 스토어 (for ```RAG```): ```Chroma DB``` (로컬 Persistence 지원)
#     * 문서 청킹은 ```LangChain MarkdownHeaderTextSplitter```를 사용하여 수행
# 3. ```RAG``` 오케스트레이션
#     * ```LangChain```
#     * 특히 ```LangChain```의  ```VectorDB Retriever```에 ```Configurable Field```를 적용하여 ```동적 메타데이터 필터링``` 적용
#     * (Optional) ```Reranker``` 사용 가능 - ```FlashrankRerank```를 통해 ```Reranker``` 모델 ```ms-marco-MultiBERT-L-12```을 사용할 수 있도록 구성
#         * 다만 본 예제에서는 ```Reranker```를 기본적으로 사용하지 않으며, ```--use-reranker``` 옵션을 통해 사용 가능
#         * 그리고 ```Reranker```를 사용하지 않는 경우와 비교 테스트를 수행해 보지는 못하였습니다 (시간 관계상 ^^;)

# %% [markdown]
# # 3. 단계별 (Step-by-Step) 수행

# %% [markdown]
# ## 3.1. 의존성 라이브러리 임포트

# %%
# %pip install -r requirements.txt

# %%
from utils.DocumentManager import DocumentManager
from utils.SingletonBedrockClient import SingletonBedrockClient

# %% [markdown]
# ## 3.2. Amazon Bedrock 클라이언트 Instantiation (Singleton)

# %%
bedrock_client = SingletonBedrockClient(region="us-west-2", runtime=True).get_instance()
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# Create new client
#   Using region: us-west-2
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-west-2.amazonaws.com)

# %% [markdown]
# ## 3.3. Document manager Instantiation

# %% [markdown]
# ### 3.3.1. Reranker 미사용

# %%
doc_manager = DocumentManager(bedrock_client, "files", return_each_line=False, strip_headers=False, log_level="INFO", rag_k_exclusion_percent=0.25, use_reranker=False)

print(len(doc_manager.all_sections))
print(doc_manager.all_sections)
for index, (page_content, metadata, _) in enumerate(doc_manager.all_sections):
    print(f"[{index}] {page_content}, {metadata}")
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 741.83it/s]
# INFO:chromadb.telemetry.product.posthog:Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# INFO:chromadb.api.segment:Collection langchain is not created.
# INFO:utils.EmbeddingManager:Deleting 72 document(s) from langchain collection
# INFO:utils.EmbeddingManager:Using embeddings from amazon.titan-embed-text-v2:0
# INFO:utils.EmbeddingManager:Creating embeddings of 72 sections from files in directory db
# INFO:utils.EmbeddingManager:Please be patient. This may take several minutes depending on the number of sections and the size of the documents.
# INFO:chromadb.api.segment:Collection langchain is not created.
# INFO:utils.EmbeddingManager:Persisting the embeddings
# /Users/sanghyou/Projects/AIML/document-normalization/.venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   warn_deprecated(
# INFO:utils.RetrievalAgentBedrock:Setting k to 4 based on the number of documents 5 and the exclusion percent 0.25.
# INFO:utils.RetrievalAgentBedrock:Prompt: input_variables=['context', 'question'] messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context'], template='You are the master in standardizing and normalizing welfare 뭉 benefits policy document that are scattered throughout a company .\nHere is pieces of context, contained in <context> tags.\n<context>\n{context}\n</context>\n\nAs output, identify outstanding policy statements relevant with input from the human.\nAlso, try to INCLUDE all the important details and EXCLUDE minor information that has relatively smaller occurrences.\nIf you find a number denoting money amount or day that deems tunable, then replace it with a placeholder like [\'blank\'] with additional remarks in output saying the following:\n"([\'blank\']을 적절한 금액이나 날짜로 대체해 주세요.)"\n \nEXCLUDE heading level starting with "#", and INCLUDE only the contents of that heading level inside the output.\n\nWhen you make output, choose the most comprehensive ones if you find several candidates of the following items: tables, bullet points, numbered lists, and blockquotes.\nAnd RETAIN the original formatting and syntax of the policy points, such as:\n1. Tables\n2. Bullet points\n3. Numbered lists\n4. Blockquotes\n\nReturn the output as plain text.\nIf you need to add some comments, add them between <llm_comments> and </llm_comments>.\nDO NOT include your comments inside output plain text.\n\nIf you don\'t know the answer, just say that you don\'t know, don\'t try to make up an answer.\n')), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], template='{question}'))]

# %% [markdown]
# ### 3.3.2. (Optional) Reranker 사용

# %% [markdown]
# 아래에서 ```Reranker```를 사용할 경우 코멘트를 해제하고 사용하시면 됩니다.

# %%
# doc_manager = DocumentManager(bedrock_client, "files", return_each_line=False, strip_headers=False, log_level="INFO", rag_k_exclusion_percent=0.25, use_reranker=True)

# %% [markdown]
# ## 3.4. 정규화된 문서 구조 생성

# %%
doc_manager.generate_norm_structure(model_id="anthropic.claude-3-sonnet-20240229-v1:0", temperature=0.1, top_p=0.9, top_k=250, max_tokens_to_sample=4096, dry_run=False)
# Out:
# INFO:utils.DocumentManager:Normalizing the structure of the document.
# INFO:utils.DocumentManager:Found 5 files in the directory.
# INFO:utils.DocumentManager:Files: ['files/한국잡월드_복리후생_1.md', 'files/한국잡월드_복리후생_2.md', 'files/한국잡월드_복리후생_3.md', 'files/한국잡월드_복리후생_4.md', 'files/한국잡월드_복리후생_5.md']
# INFO:utils.DocumentManager:Normalized document is saved to output/한국잡월드_복리후생_문서구조.md

# %% [markdown]
# ## 3.5. 정규 문서의 헤더 식별

# %%
headers = doc_manager.identify_norm_structure_headers()
print(headers)
# Out:
# ['# 복리후생 규칙 ', '## 제1장 총칙 ', '### 제1조(목적) ', '### 제2조(정의) ', '### 제3조(복리후생의 구분) ', '## 제2장 보건관리 등 지원 ', '### 제4조(건강진단) ', '### 제5조(종합검진의 지원) ', '## 제3장 맞춤형 복지제도 ', '### 제6조(복지점수의 부여) ', '### 제7조(맞춤형 복지항목) ', '### 제8조(복지점수의 관리) ', '### 제9조(복지점수의 사용) ', '### 제10조(복지카드 사용액 정산) ', '## 제4장 복리후생시설 ', '### 제11조(복리후생시설) ', '## 제5장 피복지급 ', '### 제12조(피복지급) ', '## 부 칙 ', '### 제1조(시행일) ', '### 제2조(적용기준일 특례)']

# %% [markdown]
# ## 3.6. 식별된 헤더를 기준으로 정규 문서 생성

# %%
doc_manager.normalize_document(document={i: {"header": header, "content": ""} for i, header in enumerate(headers)}, workers=4, model_id="anthropic.claude-3-sonnet-20240229-v1:0", temperature=0.1, top_p=0.9, top_k=250, max_tokens_to_sample=4096, dry_run=False)
# Out:
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=37ee5c0f-f955-4001-a60e-a6dafb710fa6] Start: 복지 정책 항목 ### 제1조(목적) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=9b0909d6-76cf-40b5-94e1-9bbed72918ce] Start: 복지 정책 항목 ### 제2조(정의) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=9f5748b0-b26b-46c2-b36d-0f186bbf02f8] Start: 복지 정책 항목 ## 제1장 총칙 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=7d24536b-ce91-4664-8bf6-4b0dfab5ea47] Start: 복지 정책 항목 # 복리후생 규칙 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=37ee5c0f-f955-4001-a60e-a6dafb710fa6] End: [Document(page_content='## 제1장 총칙  \n### 제1조(목적)\n이 규칙은 한국잡월드(이하 "잡월드"라고 한다) 소속 임직원 복리후생제도에 관한 기본적인 사항을 정하는 것을 목적으로 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제1조(목적)'}), Document(page_content='## 제1장 총칙  \n### 제1조(목적)\n이 규칙은 한국잡월드(이하 "잡월드"라고 한다) 소속 임직원 복리후생제도에 관한 기본적인 사항을 정하는 것을 목적으로 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제1조(목적)'}), Document(page_content='# 복리후생 규칙  \n## 제1장 총칙  \n### 제1조(목적)\n이 규칙은 한국잡월드(이하 "잡월드"라고 한다)에 근무하는 모든 임직원들의 복리후생 제도에 대한 기본적인 사항들을 구체적이고 상세하게 규정함으로써, 임직원들의 사기 진작과 근무 만족도 제고를 통해 조직의 생산성 향상에 기여함을 목적으로 한다. 아울러 본 규칙을 통해 공정하고 투명한 복리후생 제도 운영의 기반을 마련하고자 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제1조(목적)'}), Document(page_content='### 제1조(목적)\n이 규칙은 한국잡월드 소속 임직원 복리후생제도에 관한 기본적인 사항을 정하는 것을 목적으로 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제1조(목적)'})]
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=9f5748b0-b26b-46c2-b36d-0f186bbf02f8] End: [Document(page_content='# 복리후생 규칙  \n## 제1장 총칙  \n### 제2조(정의)\n이 규칙에서 사용하는 용어의 정의는 다음 각 호와 같다.\n1. "복지점수"란 직원 개인이 사용할 수 있는 복지예산의 단위를 말하며, 1포인트는 1000원으로 한다.\n2. "복지카드"란 복지서비스를 지원하기 위하여 선정된 복지카드 발행회사가 발급한 개인 명의의 신용카드를 말한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제2조(정의)'}), Document(page_content='### 제2조(정의)\n이 규칙에서 사용하는 용어의 정의는 다음 각 호와 같다.\n1. "맞춤형 복지제도"란 직원 개인에게 배정된 복지예산 한도 내에서 직원이 복지항목 및 수혜수준을 사전에 설계된 복지항목 중에서 선택할 수 있게 하는 제도를 말한다.\n2. "복지점수"란 직원 개인이 사용할 수 있는 복지예산의 단위를 말하며, 1포인트는 1원으로 한다.\n3. "복리후생관"이란 맞춤형 복지제도의 운영을 위하여 잡월드와 위탁계약을 체결한 업체가 운영하는 온라인 사이트를 말한다.\n4. "복지카드"란 복지서비스를 지원하기 위하여 선정된 복지카드 발행회사가 발급한 개인 명의의 신용카드 또는 체크카드를 말한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제2조(정의)'}), Document(page_content='## 제1장 총칙  \n### 제1조(목적)\n이 규칙은 한국잡월드(이하 "잡월드"라고 한다) 소속 임직원 복리후생제도에 관한 기본적인 사항을 정하는 것을 목적으로 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제1조(목적)'}), Document(page_content='## 제1장 총칙  \n### 제1조(목적)\n이 규칙은 한국잡월드(이하 "잡월드"라고 한다) 소속 임직원 복리후생제도에 관한 기본적인 사항을 정하는 것을 목적으로 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제1조(목적)'})]
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=9b0909d6-76cf-40b5-94e1-9bbed72918ce] End: [Document(page_content='### 제2조(정의)\n이 규칙에서 사용하는 용어의 정의는 다음 각 호와 같다.\n1. "맞춤형 복지제도"란 직원 개인에게 배정된 복지예산 한도 내에서 직원이 복지항목 및 수혜수준을 사전에 설계된 복지항목 중에서 선택할 수 있게 하는 제도를 말한다.\n2. "복지점수"란 직원 개인이 사용할 수 있는 복지예산의 단위를 말하며, 1포인트는 1원으로 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제2조(정의)'}), Document(page_content='### 제2조(정의)\n이 규칙에서 사용하는 용어의 정의는 다음 각 호와 같다.\n1. "맞춤형 복지제도"란 직원 개인에게 배정된 복지예산 한도 내에서 직원이 복지항목 및 수혜수준을 사전에 설계된 복지항목 중에서 선택할 수 있게 하는 제도를 말한다.\n2. "복지점수"란 직원 개인이 사용할 수 있는 복지예산의 단위를 말하며, 1포인트는 1원으로 한다.\n3. "복리후생관"이란 맞춤형 복지제도의 운영을 위하여 잡월드와 위탁계약을 체결한 업체가 운영하는 온라인 사이트를 말한다.\n4. "복지카드"란 복지서비스를 지원하기 위하여 선정된 복지카드 발행회사가 발급한 개인 명의의 신용카드 또는 체크카드를 말한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제2조(정의)'}), Document(page_content='### 제2조(정의)\n이 규칙에서 사용되는 용어들의 정의는 다음과 같다.\n1. "맞춤형 복지제도"란 잡월드에서 근무하는 개별 직원들에게 일정 한도의 복지 예산을 배정하고, 직원들이 자신의 선호와 필요에 따라 다양한 복지 항목들 중에서 자유롭게 선택하여 수혜를 받을 수 있도록 설계된 제도를 의미한다. 이를 통해 직원 개개인의 만족도를 제고하고 조직에 대한 애사심을 고취시키고자 한다.\n2. "복지점수"란 맞춤형 복지제도에서 직원 개인에게 배정되는 일종의 가상 화폐로서, 1포인트는 1원의 가치를 지닌다. 직원들은 자신에게 주어진 복지점수 한도 내에서 원하는 복지 항목을 선택하여 수혜를 받게 된다.\n3. "복리후생관"이란 잡월드에서 맞춤형 복지제도를 원활하게 운영하기 위해 외부 전문 업체와 위탁계약을 맺고 운영하는 온라인 플랫폼으로, 직원들이 편리하게 복지 항목을 선택하고 신청할 수 있도록 지원한다.\n4. "복지카드"란 복지서비스 이용의 편의성을 높이기 위해 도입된 전용 신용카드 또는 체크카드로서, 잡월드와 계약을 맺은 카드사에서 직원 개인 명의로 발급한다. 직원들은 복지카드를 사용하여 다양한 복지 항목의 비용을 간편하게 결제할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제2조(정의)'}), Document(page_content='# 복리후생 규칙  \n## 제1장 총칙  \n### 제2조(정의)\n이 규칙에서 사용하는 용어의 정의는 다음 각 호와 같다.\n1. "복지점수"란 직원 개인이 사용할 수 있는 복지예산의 단위를 말하며, 1포인트는 1000원으로 한다.\n2. "복지카드"란 복지서비스를 지원하기 위하여 선정된 복지카드 발행회사가 발급한 개인 명의의 신용카드를 말한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제2조(정의)'})]
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=7d24536b-ce91-4664-8bf6-4b0dfab5ea47] End: [Document(page_content='# 복리후생 규칙  \n## 제1장 총칙  \n### 제1조(목적)\n이 규칙은 한국잡월드(이하 "잡월드"라고 한다)에 근무하는 모든 임직원들의 복리후생 제도에 대한 기본적인 사항들을 구체적이고 상세하게 규정함으로써, 임직원들의 사기 진작과 근무 만족도 제고를 통해 조직의 생산성 향상에 기여함을 목적으로 한다. 아울러 본 규칙을 통해 공정하고 투명한 복리후생 제도 운영의 기반을 마련하고자 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제1조(목적)'}), Document(page_content='# 복리후생 규칙  \n제정 2015. 6. 19. 규칙 제83호', metadata={'Header 1': '복리후생 규칙'}), Document(page_content='# 복리후생 규칙  \n제정 2015. 6. 19. 규칙 제83호', metadata={'Header 1': '복리후생 규칙'}), Document(page_content='### 제3조(복리후생의 구분)\n임직원의 복리후생은 다음 각 호에 따라 구분한다.\n1. 보건관리 등 지원\n2. 맞춤형 복지제도\n3. 복리후생시설\n4. 피복지급', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제3조(복리후생의 구분)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 제1조(목적)
# 이 규칙은 한국잡월드(이하 "잡월드"라고 한다)에 근무하는 모든 임직원들의 복리후생 제도에 대한 기본적인 사항들을 구체적이고 상세하게 규정함으로써, 임직원들의 사기 진작과 근무 만족도 제고를 통해 조직의 생산성 향상에 기여함을 목적으로 한다. 아울러 본 규칙을 통해 공정하고 투명한 복리후생 제도 운영의 기반을 마련하고자 한다.
#
# 제3조(복리후생의 구분)
# 임직원의 복리후생은 다음 각 호에 따라 구분한다.
# 1. 보건관리 등 지원
# 2. 맞춤형 복지제도
# 3. 복리후생시설
# 4. 피복지급
#
# <llm_comments>
# 제공된 문서에서 복리후생 규칙의 목적과 복리후생 구분에 대한 내용을 발췌하여 출력했습니다. 구체적인 세부 정책 내용은 포함되어 있지 않았습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=0462bf14-156c-4a5c-9abc-f7914535f57d] Start: 복지 정책 항목 ### 제3조(복리후생의 구분) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=0462bf14-156c-4a5c-9abc-f7914535f57d] End: [Document(page_content='### 제3조(복리후생의 구분)\n임직원의 복리후생은 다음 각 호에 따라 구분한다.\n1. 보건관리 등 지원\n2. 맞춤형 복지제도\n3. 복리후생시설\n4. 피복지급', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제3조(복리후생의 구분)'}), Document(page_content='### 제3조(복리후생의 구분)\n잡월드 임직원들의 복리후생은 크게 다음의 4가지 영역으로 구분한다.\n1. 보건관리 등 지원: 직원들의 신체적, 정신적 건강 유지 및 증진을 위한 건강검진, 예방접종, 의료비 지원 등\n2. 맞춤형 복지제도: 개별 직원의 선호와 필요에 맞춰 다양한 복지 항목을 선택할 수 있는 포인트 기반 복지 제도\n3. 복리후생시설: 직원들의 편의와 여가 활동 지원을 위해 회사에서 직접 설치하거나 위탁 운영하는 휴양시설, 사내 복지시설 등\n4. 피복지급: 업무 특성상 피복 착용이 필요한 직원들에 대한 근무복, 작업복 등의 피복 지급', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제1장 총칙', 'Header 3': '제3조(복리후생의 구분)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 이 규칙은 한국잡월드(이하 "잡월드"라고 한다)에 근무하는 모든 임직원들의 복리후생 제도에 대한 기본적인 사항들을 구체적이고 상세하게 규정함으로써, 임직원들의 사기 진작과 근무 만족도 제고를 통해 조직의 생산성 향상에 기여함을 목적으로 한다. 아울러 본 규칙을 통해 공정하고 투명한 복리후생 제도 운영의 기반을 마련하고자 한다.
#
# <llm_comments>
# 제1조(목적)에 규정된 내용을 그대로 출력했습니다. 이 조항은 복리후생 규칙의 목적을 상세히 설명하고 있습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=c3996606-5e52-4a2d-8c2b-7f6d0be6bc4a] Start: 복지 정책 항목 ## 제2장 보건관리 등 지원 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=c3996606-5e52-4a2d-8c2b-7f6d0be6bc4a] End: [Document(page_content='## 제2장 보건관리 등 지원  \n### 제4조(건강진단)\n① 임직원의 건강진단을 정기적으로 실시하여야 하며 필요한 경우에는 수시로 건강진단 또는 예방접종을 실시할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제2장 보건관리 등 지원', 'Header 3': '제4조(건강진단)'}), Document(page_content='### 제5조(종합검진의 지원)\n① 임원 및 근속기간 1년 이상인 직원에 대하여 예산범위 내에서 격년주기로 종합건강검진을 지원할 수 있다.\n② 전항의 규정은 적용기준일(매년 1월 1일) 현재 휴직자를 제외한 재직 임직원에게 적용한다.\n③ 제1항의 건강검진을 위하여 외부의료기관을 지정하거나 복리후생관을 이용하게 하여 실시할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제2장 보건관리 등 지원', 'Header 3': '제5조(종합검진의 지원)'}), Document(page_content='## 제2장 보건관리 등 지원  \n### 제4조(건강진단)\n① 임직원의 건강진단을 정기적으로 실시하여야 하며 필요한 경우에는 수시로 건강진단 또는 예방접종을 실시할 수 있다.\n② 직원은 정당한 사유 없이 전항의 건강진단 또는 예방접종을 거부하여서는 아니 된다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제2장 보건관리 등 지원', 'Header 3': '제4조(건강진단)'}), Document(page_content='## 제2장 보건관리 등 지원  \n### 제4조(건강진단)\n① 잡월드는 임직원의 건강 유지 및 증진을 위해 매년 정기적으로 건강진단을 실시하며, 필요에 따라 수시 건강진단이나 예방접종을 시행할 수 있다. 이를 통해 직원들이 업무에 전념할 수 있는 건강한 환경을 조성하고자 한다.\n② 모든 직원은 회사에서 실시하는 건강진단이나 예방접종에 성실히 응할 의무가 있으며, 정당한 사유 없이 이를 거부해서는 안 된다. 건강한 직장 분위기 조성을 위해 직원 개개인의 적극적인 협조가 필요하다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제2장 보건관리 등 지원', 'Header 3': '제4조(건강진단)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 제2조(정의)에 규정된 주요 내용은 다음과 같습니다:
#
# 1. "맞춤형 복지제도"란 직원 개인에게 배정된 복지예산 한도 내에서 직원이 복지항목 및 수혜수준을 사전에 설계된 복지항목 중에서 선택할 수 있게 하는 제도를 말한다.
#
# 2. "복지점수"란 직원 개인이 사용할 수 있는 복지예산의 단위를 말하며, 1포인트는 1000원으로 한다. (['blank']을 적절한 금액으로 대체해 주세요.)
#
# 3. "복리후생관"이란 맞춤형 복지제도의 운영을 위하여 외부 전문업체와 위탁계약을 체결한 온라인 사이트를 말한다.
#
# 4. "복지카드"란 복지서비스를 지원하기 위하여 선정된 복지카드 발행회사가 발급한 개인 명의의 신용카드를 말한다.
#
# <llm_comments>
# 제2조에서는 맞춤형 복지제도, 복지점수, 복리후생관, 복지카드 등의 주요 용어를 정의하고 있습니다. 복지점수의 경우 1포인트당 금액이 명시되어 있는데, 이는 회사 정책에 따라 변경될 수 있으므로 ['blank']로 표시하였습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=7ca237a6-8033-4a8b-b9fa-99433eca32b2] Start: 복지 정책 항목 ### 제4조(건강진단) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 제1장 총칙에 규정된 주요 내용은 다음과 같습니다:
#
# 제1조(목적)
# 이 규칙은 한국잡월드(이하 "잡월드"라고 한다) 소속 임직원 복리후생제도에 관한 기본적인 사항을 정하는 것을 목적으로 한다.
#
# 제2조(정의)
# 1. "맞춤형 복지제도"란 직원 개인에게 배정된 복지예산 한도 내에서 직원이 복지항목 및 수혜수준을 사전에 설계된 복지항목 중에서 선택할 수 있게 하는 제도를 말한다.
# 2. "복지점수"란 직원 개인이 사용할 수 있는 복지예산의 단위를 말하며, 1포인트는 ['blank']원으로 한다. (["'blank'을 적절한 금액으로 대체해 주세요."])
# 3. "복리후생관"이란 맞춤형 복지제도의 운영을 위하여 잡월드와 위탁계약을 체결한 업체가 운영하는 온라인 사이트를 말한다.
# 4. "복지카드"란 복지서비스를 지원하기 위하여 선정된 복지카드 발행회사가 발급한 개인 명의의 신용카드 또는 체크카드를 말한다.
#
# <llm_comments>
# 제1장 총칙에서는 복리후생 규칙의 목적과 주요 용어에 대한 정의를 제시하고 있습니다. 특히 "맞춤형 복지제도", "복지점수", "복리후생관", "복지카드"에 대한 정의를 상세히 설명하고 있습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=8e6992db-4db0-4cda-a3f2-faae08190673] Start: 복지 정책 항목 ### 제5조(종합검진의 지원) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=7ca237a6-8033-4a8b-b9fa-99433eca32b2] End: [Document(page_content='## 제2장 보건관리 등 지원  \n### 제4조(건강진단)\n① 임직원의 건강진단을 정기적으로 실시하여야 하며 필요한 경우에는 수시로 건강진단 또는 예방접종을 실시할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제2장 보건관리 등 지원', 'Header 3': '제4조(건강진단)'}), Document(page_content='## 제2장 보건관리 등 지원  \n### 제4조(건강진단)\n① 임직원의 건강진단을 정기적으로 실시하여야 하며 필요한 경우에는 수시로 건강진단 또는 예방접종을 실시할 수 있다.\n② 직원은 정당한 사유 없이 전항의 건강진단 또는 예방접종을 거부하여서는 아니 된다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제2장 보건관리 등 지원', 'Header 3': '제4조(건강진단)'}), Document(page_content='## 제2장 보건관리 등 지원  \n### 제4조(건강진단)\n① 잡월드는 임직원의 건강 유지 및 증진을 위해 매년 정기적으로 건강진단을 실시하며, 필요에 따라 수시 건강진단이나 예방접종을 시행할 수 있다. 이를 통해 직원들이 업무에 전념할 수 있는 건강한 환경을 조성하고자 한다.\n② 모든 직원은 회사에서 실시하는 건강진단이나 예방접종에 성실히 응할 의무가 있으며, 정당한 사유 없이 이를 거부해서는 안 된다. 건강한 직장 분위기 조성을 위해 직원 개개인의 적극적인 협조가 필요하다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제2장 보건관리 등 지원', 'Header 3': '제4조(건강진단)'})]
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=8e6992db-4db0-4cda-a3f2-faae08190673] End: [Document(page_content='### 제5조(종합검진의 지원)\n① 임원 및 근속기간 1년 이상인 직원에 대하여 예산범위 내에서 격년주기로 종합건강검진을 지원할 수 있다.\n② 전항의 규정은 적용기준일(매년 1월 1일) 현재 휴직자를 제외한 재직 임직원에게 적용한다.\n③ 제1항의 건강검진을 위하여 외부의료기관을 지정하거나 복리후생관을 이용하게 하여 실시할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제2장 보건관리 등 지원', 'Header 3': '제5조(종합검진의 지원)'}), Document(page_content='### 제5조(종합검진의 지원)\n① 잡월드는 일정 직급 이상의 임원과 근속년수 1년 이상인 직원들을 대상으로 2년에 한 번씩 종합건강검진 비용을 지원한다. 다만 예산 사정 등을 고려하여 지원 대상과 주기는 조정될 수 있다.\n② 종합건강검진 대상은 매년 1월 1일을 기준으로 하되, 장기 휴직중인 직원의 경우는 제외한다. 검진 대상 선정의 공정성과 형평성 제고를 위해 명확한 기준을 적용한다.\n③ 회사는 종합건강검진의 품질 향상과 직원 편의 도모를 위해 외부 전문 의료기관을 지정하거나 복리후생관을 통한 검진을 진행할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제2장 보건관리 등 지원', 'Header 3': '제5조(종합검진의 지원)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 잡월드 임직원들의 복리후생은 크게 다음의 4가지 영역으로 구분됩니다.
#
# 1. 보건관리 등 지원: 직원들의 신체적, 정신적 건강 유지 및 증진을 위한 건강검진, 예방접종, 의료비 지원 등
#
# 2. 맞춤형 복지제도: 개별 직원의 선호와 필요에 맞춰 다양한 복지 항목을 선택할 수 있는 포인트 기반 복지 제도
#
# 3. 복리후생시설: 직원들의 편의와 여가 활동 지원을 위해 회사에서 직접 설치하거나 위탁 운영하는 휴양시설, 사내 복지시설 등
#
# 4. 피복지급: 업무 특성상 피복 착용이 필요한 직원들에 대한 근무복, 작업복 등의 피복 지급
#
# <llm_comments>
# 제3조(복리후생의 구분)에 규정된 내용을 그대로 출력했습니다. 구체적인 세부 사항은 없지만 4가지 주요 복리후생 영역을 명시하고 있습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=19e776c2-8737-4d4f-acdc-b07646ffea13] Start: 복지 정책 항목 ## 제3장 맞춤형 복지제도 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=19e776c2-8737-4d4f-acdc-b07646ffea13] End: [Document(page_content='## 제3장 맞춤형 복지제도  \n### 제6조(복지점수의 부여)\n① 복지점수는 [별표 1]을 기준으로 전직원에 대하여 부여한다.\n② 복지점수의 산정 기준일은 매 회계연도 시작일로 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제6조(복지점수의 부여)'}), Document(page_content='## 제3장 맞춤형 복지제도  \n### 제6조(복지점수의 부여)\n① 복지점수는 [별표 1]을 기준으로 전직원에 대하여 부여한다.\n② 휴직자에 대한 맞춤형 복지제도의 적용 기준은 [별표 2]와 같다.\n③ 복지점수의 산정 기준일은 매 회계연도 시작일로 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제6조(복지점수의 부여)'}), Document(page_content='### 제7조(맞춤형 복지항목)\n복지항목은 자율항목과 의료비보장의 특별항목으로 구성한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제7조(맞춤형 복지항목)'}), Document(page_content='### 제7조(맞춤형 복지항목)\n복지항목은 자율항목과 의료비보장의 특별항목으로 구성한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제7조(맞춤형 복지항목)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 제2장 보건관리 등 지원에 관한 주요 정책 내용은 다음과 같습니다.
#
# ① 임직원의 건강진단을 정기적으로 실시하여야 하며 필요한 경우에는 수시로 건강진단 또는 예방접종을 실시할 수 있다.
# ② 임원 및 근속기간 1년 이상인 직원에 대하여 예산범위 내에서 격년주기로 종합건강검진을 지원할 수 있다. 이때 적용기준일(매년 1월 1일) 현재 휴직자는 제외된다.
# ③ 종합건강검진을 위해 외부 의료기관을 지정하거나 복리후생관을 이용하게 할 수 있다.
# ④ 직원은 정당한 사유 없이 건강진단 또는 예방접종을 거부해서는 안 된다.
#
# <llm_comments>
# - 정기 건강진단 및 수시 건강진단/예방접종 실시
# - 1년 이상 근속자에 대한 격년 종합검진 지원 (단, 휴직자 제외)
# - 외부 의료기관 또는 복리후생관 이용 가능
# - 직원은 정당한 사유 없이 건강진단/예방접종 거부 불가
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=75907d1f-44c5-44e0-a32b-e7011d1f7d0f] Start: 복지 정책 항목 ### 제6조(복지점수의 부여) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=75907d1f-44c5-44e0-a32b-e7011d1f7d0f] End: [Document(page_content='## 제3장 맞춤형 복지제도  \n### 제6조(복지점수의 부여)\n① 복지점수는 [별표 1]을 기준으로 전직원에 대하여 부여한다.\n② 복지점수의 산정 기준일은 매 회계연도 시작일로 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제6조(복지점수의 부여)'}), Document(page_content='## 제3장 맞춤형 복지제도  \n### 제6조(복지점수의 부여)\n① 모든 직원에게는 연간 [별표 1]에서 정한 기준에 따라 복지점수가 부여된다. 이를 통해 직원들의 다양한 복지 수요를 충족시키고자 한다.\n② [별표 2]와 같이 휴직 사유 및 기간에 따라 복지점수 부여에서 일부 제한이 있을 수 있으며, 형평성 있는 제도 설계를 위해 휴직자 관리에 유의한다.\n③ 복지점수는 회계연도 시작일을 기준으로 산정하되, 신규 입사자 등은 일할계산하여 적용한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제6조(복지점수의 부여)'}), Document(page_content='## 제3장 맞춤형 복지제도  \n### 제6조(복지점수의 부여)\n① 복지점수는 [별표 1]을 기준으로 전직원에 대하여 부여한다.\n② 휴직자에 대한 맞춤형 복지제도의 적용 기준은 [별표 2]와 같다.\n③ 복지점수의 산정 기준일은 매 회계연도 시작일로 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제6조(복지점수의 부여)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 잡월드는 임직원의 건강 유지 및 증진을 위해 다음과 같은 정책을 시행하고 있습니다.
#
# ① 잡월드는 임직원의 건강 유지 및 증진을 위해 매년 정기적으로 건강진단을 실시하며, 필요에 따라 수시 건강진단이나 예방접종을 시행할 수 있다. 이를 통해 직원들이 업무에 전념할 수 있는 건강한 환경을 조성하고자 한다.
#
# ② 모든 직원은 회사에서 실시하는 건강진단이나 예방접종에 성실히 응할 의무가 있으며, 정당한 사유 없이 이를 거부해서는 안 된다. 건강한 직장 분위기 조성을 위해 직원 개개인의 적극적인 협조가 필요하다.
#
# <llm_comments>
# 제4조(건강진단) 항목에서 중요한 정책 내용을 모두 포함하여 출력했습니다. 세부 사항이나 예외 조항 등은 생략하고 핵심 정책만 간략하게 정리했습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=e02837b9-4ddc-413a-8073-b813d5338d53] Start: 복지 정책 항목 ### 제7조(맞춤형 복지항목) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=e02837b9-4ddc-413a-8073-b813d5338d53] End: [Document(page_content='### 제7조(맞춤형 복지항목)\n복지항목은 자율항목과 의료비보장의 특별항목으로 구성한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제7조(맞춤형 복지항목)'}), Document(page_content='### 제7조(맞춤형 복지항목)\n복지항목은 자율항목과 의료비보장의 특별항목으로 구성한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제7조(맞춤형 복지항목)'}), Document(page_content='### 제7조(맞춤형 복지항목)\n맞춤형 복지제도에서 직원들이 선택할 수 있는 복지 항목은 크게 자율항목과 의료비 지원을 위한 특별항목으로 구분된다. 자율항목은 건강관리, 자기계발, 가족친화, 여가활동 등 직원들의 다양한 니즈를 충족시킬 수 있는 폭넓은 영역들로 구성된다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제7조(맞춤형 복지항목)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 제5조(종합검진의 지원)에 대한 정책 내용은 다음과 같습니다:
#
# ① 잡월드는 일정 직급 이상의 임원과 근속년수 1년 이상인 직원들을 대상으로 2년에 한 번씩 종합건강검진 비용을 지원한다. 다만 예산 사정 등을 고려하여 지원 대상과 주기는 조정될 수 있다.
#
# ② 종합건강검진 대상은 매년 1월 1일을 기준으로 하되, 장기 휴직중인 직원의 경우는 제외한다. 검진 대상 선정의 공정성과 형평성 제고를 위해 명확한 기준을 적용한다.
#
# ③ 회사는 종합건강검진의 품질 향상과 직원 편의 도모를 위해 외부 전문 의료기관을 지정하거나 복리후생관을 통한 검진을 진행할 수 있다.
#
# <llm_comments>
# - 2년마다 종합건강검진 비용을 지원하되, 예산 사정에 따라 지원 대상과 주기가 조정될 수 있음
# - 매년 1월 1일 기준으로 대상자를 선정하며, 장기 휴직자는 제외됨
# - 검진 대상 선정 시 공정성과 형평성을 위해 명확한 기준을 적용함
# - 품질 향상과 직원 편의를 위해 외부 의료기관 또는 복리후생관을 통해 검진을 진행할 수 있음
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=cc5ca23a-9598-4091-98d1-67db70fffdc1] Start: 복지 정책 항목 ### 제8조(복지점수의 관리) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=cc5ca23a-9598-4091-98d1-67db70fffdc1] End: [Document(page_content='### 제8조(복지점수의 관리)\n① 회계연도 중 신규 입사, 승진, 퇴사 등 인사 발령에 따른 복지점수는 일할계산하여 관리한다.\n② 단시간 근로자의 복지점수는 법정 근로시간에 비례하여 근무시간 만큼 차등 지급함으로써 형평성을 기한다.\n③ 퇴직하는 직원에 대해서는 기 사용한 복지점수를 정산하여 과다 사용분에 대한 반납을 요구할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제8조(복지점수의 관리)'}), Document(page_content='### 제8조(복지점수의 관리)\n① 회계연도 중 신규임용 등의 신분변동이 있는 경우 변동사유가 발생한 날을 기준으로 일할계산하여 부여한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제8조(복지점수의 관리)'}), Document(page_content='### 제8조(복지점수의 관리)\n① 회계연도 중 신규임용 등의 신분변동이 있는 경우 변동사유가 발생한 날을 기준으로 일할계산하여 부여한다.\n② 단시간근로자는 해당근로자의 소정근로시간을 기준으로 법정근로시간에 비례하여 지급한다.\n③ 근로계약이 종료되는 직원에 대해서는 이미 사용한 복지점수를 일할계산하여 정산한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제8조(복지점수의 관리)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 제3장 맞춤형 복지제도에 규정된 내용은 다음과 같습니다:
#
# 제6조(복지점수의 부여)
# ① 복지점수는 [별표 1]을 기준으로 전직원에 대하여 부여한다.
# ② 휴직자에 대한 맞춤형 복지제도의 적용 기준은 [별표 2]와 같다.
# ③ 복지점수의 산정 기준일은 매 회계연도 시작일로 한다.
#
# 제7조(맞춤형 복지항목)
# 복지항목은 자율항목과 의료비보장의 특별항목으로 구성한다.
#
# <llm_comments>
# 제6조는 복지점수 부여 기준과 산정 기준일을 규정하고 있으며, 제7조는 맞춤형 복지항목이 자율항목과 의료비보장 특별항목으로 구성됨을 명시하고 있습니다. 별표 1과 별표 2의 구체적인 내용은 제시되지 않았습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=47241f72-0bdd-43ed-81ce-908b6bf425a2] Start: 복지 정책 항목 ### 제9조(복지점수의 사용) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=47241f72-0bdd-43ed-81ce-908b6bf425a2] End: [Document(page_content='### 제9조(복지점수의 사용)\n① 직원들은 매년 11월 말까지 자신에게 배정된 복지점수를 전액 사용해야 하며, 미사용 점수는 이월되지 않는다.\n② 복지점수는 현금으로 대체 지급을 요구할 수 없으며, 오직 해당 연도 내 복지 항목 이용에만 사용할 수 있다.\n③ 이는 예산 관리의 효율성을 제고하고 직원들의 복지 혜택을 극대화하기 위함이다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제9조(복지점수의 사용)'}), Document(page_content='### 제9조(복지점수의 사용)\n① 복지점수는 해당항목에 맞춰 당해 연도 11월말까지 사용하여야 한다.\n② 전항의 기간까지 사용하지 못한 복지점수는 소멸된다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제9조(복지점수의 사용)'}), Document(page_content='### 제9조(복지점수의 사용)\n① 복지점수는 해당항목에 맞춰 당해 연도 11월말까지 사용하여야 한다.\n② 전항의 기간까지 사용하지 못한 복지점수는 소멸된다.\n③ 복지점수는 금전으로 청구하지 못한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제9조(복지점수의 사용)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 제6조(복지점수의 부여)에 대한 정책 내용은 다음과 같습니다:
#
# ① 모든 직원에게는 연간 [별표 1]에서 정한 기준에 따라 복지점수가 부여된다. 이를 통해 직원들의 다양한 복지 수요를 충족시키고자 한다.
#
# ② [별표 2]와 같이 휴직 사유 및 기간에 따라 복지점수 부여에서 일부 제한이 있을 수 있으며, 형평성 있는 제도 설계를 위해 휴직자 관리에 유의한다.
#
# ③ 복지점수는 회계연도 시작일을 기준으로 산정하되, 신규 입사자 등은 일할계산하여 적용한다.
#
# <llm_comments>
# - 복지점수 부여 기준은 [별표 1]에 따르며, 이를 통해 직원들의 복지 수요를 충족시키고자 함
# - 휴직자에 대해서는 [별표 2]에 따라 복지점수 부여에 제한이 있을 수 있음
# - 복지점수는 회계연도 시작일 기준으로 산정하되, 신규 입사자 등은 일할계산 적용
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=8333ca67-6525-40f2-b1dc-19d7738085cc] Start: 복지 정책 항목 ### 제10조(복지카드 사용액 정산) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=8333ca67-6525-40f2-b1dc-19d7738085cc] End: [Document(page_content='### 제10조(복지카드 사용액 정산)\n① 복지카드 사용자는 복리후생관에 접속하여 사용액에 대해 차감신청을 하여야 한다. 차감신청이 되지 않는 항목에 대해서는 소명신청을 하여야 한다.\n② 소명신청 내역에 대해서는 [별표 3]을 기준으로 매월 단위로 승인여부를 결정한다.\n③ 소명신청 불승인 항목은 복지점수에서 차감하지 아니한다.\n④ 1년 이하의 기간의 정함이 있는 근로자의 경우, <서식 1>의 복지포인트 비용 청구서와 영수증 등의 증빙자료를 함께 제출하여 차감신청을 할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제10조(복지카드 사용액 정산)'}), Document(page_content='### 제10조(복지카드 사용액 정산)\n① 직원들은 복지카드 사용 후 복리후생관을 통해 사용 내역을 신청하고, 복지점수에서 차감되도록 관리해야 한다.\n② 복리후생관에서 자동 승인되지 않은 건에 대해서는 증빙자료와 함께 소명 신청을 해야 하며, 심사를 거쳐 승인 여부가 결정된다.\n③ 부적격한 사용 건으로 판명될 경우 복지점수 차감 없이 직원 본인 부담으로 처리된다.\n④ 단기계약직의 경우 복리후생관 사용이 제한될 수 있으므로, 비용 청구서와 영수증을 제출하여 수기 정산을 신청할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 맞춤형 복지제도', 'Header 3': '제10조(복지카드 사용액 정산)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 맞춤형 복지제도에서 직원들이 선택할 수 있는 복지 항목은 크게 자율항목과 의료비 지원을 위한 특별항목으로 구분된다. 자율항목은 건강관리, 자기계발, 가족친화, 여가활동 등 직원들의 다양한 니즈를 충족시킬 수 있는 폭넓은 영역들로 구성된다.
#
# <llm_comments>
# 제공된 맥락에서 제7조(맞춤형 복지항목)에 대한 구체적인 내용을 확인할 수 있습니다. 복지 항목이 자율항목과 의료비보장 특별항목으로 구성되어 있으며, 자율항목에는 건강관리, 자기계발, 가족친화, 여가활동 등의 영역이 포함된다고 설명하고 있습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=2b51aec9-49ac-4357-b435-a3a5fd0a7280] Start: 복지 정책 항목 ## 제4장 복리후생시설 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=2b51aec9-49ac-4357-b435-a3a5fd0a7280] End: [Document(page_content='## 제4장 복리후생시설  \n### 제11조(복리후생시설)\n① 임직원의 복리증진을 위하여 다음 각 호의 복리후생시설을 설치ㆍ운영할 수 있으며, 시행에 필요한 사항은 이사장이 별도로 정한다.\n1. 휴양시설\n2. 사내복지시설(휴게실, 식당, 매점 등)', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제4장 복리후생시설', 'Header 3': '제11조(복리후생시설)'}), Document(page_content='## 제4장 복리후생시설  \n### 제11조(복리후생시설)\n① 임직원의 복리증진을 위하여 다음 각 호의 복리후생시설을 설치ㆍ운영할 수 있으며, 시행에 필요한 사항은 이사장이 별도로 정한다.\n1. 휴양시설\n2. 사내복지시설(휴게실, 식당, 매점 등)\n② 제1항의 규정에 따라 복리후생시설을 신축ㆍ구입ㆍ임차하여 제공할 수 있으며, 예산의 범위 내에서 소요경비 등을 지급할 수 있다.\n③ 휴양시설의 이용은 『직원휴양시설 운영규칙』에 따른다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제4장 복리후생시설', 'Header 3': '제11조(복리후생시설)'}), Document(page_content='## 제4장 복리후생시설  \n### 제11조(복리후생시설)\n① 잡월드는 직원들의 삶의 질 제고를 위해 다음의 시설들을 설치, 운영할 수 있으며, 필요시 외부 위탁도 가능하다.\n1. 휴양시설: 직원들의 재충전과 심신 단련을 위한 콘도, 펜션 등의 휴양 시설\n2. 사내복지시설: 직원들이 편히 쉬고 즐길 수 있는 휴게실, 구내식당, 사내 매점 등\n② 회사는 직원들의 만족도 제고를 위해 새로운 복지시설을 신축/구입하거나 외부 시설을 임차하여 제공할 수 있다.\n③ 휴양시설 이용에 관한 구체적인 기준과 절차는 『직원휴양시설 운영규칙』에 따른다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제4장 복리후생시설', 'Header 3': '제11조(복리후생시설)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 다음은 ### 제9조(복지점수의 사용)에 규정된 내용입니다:
#
# ① 직원들은 매년 ['blank']까지 자신에게 배정된 복지점수를 전액 사용해야 하며, 미사용 점수는 이월되지 않는다. (['blank']을 적절한 날짜로 대체해 주세요.)
# ② 복지점수는 현금으로 대체 지급을 요구할 수 없으며, 오직 해당 연도 내 복지 항목 이용에만 사용할 수 있다.
# ③ 이는 예산 관리의 효율성을 제고하고 직원들의 복지 혜택을 극대화하기 위함이다.
#
# ① 복지점수는 해당항목에 맞춰 당해 연도 ['blank']까지 사용하여야 한다. (['blank']을 적절한 날짜로 대체해 주세요.)
# ② 전항의 기간까지 사용하지 못한 복지점수는 소멸된다.
#
# ① 복지점수는 해당항목에 맞춰 당해 연도 ['blank']까지 사용하여야 한다. (['blank']을 적절한 날짜로 대체해 주세요.)
# ② 전항의 기간까지 사용하지 못한 복지점수는 소멸된다.
# ③ 복지점수는 금전으로 청구하지 못한다.
#
# <llm_comments>
# 위 내용은 복지점수 사용 기한, 현금 대체 불가, 미사용 점수 소멸 등의 규정을 포함하고 있습니다. 구체적인 날짜는 placeholder로 대체하였습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=2d2ee93a-ccdb-4bdd-ab3c-98067781814b] Start: 복지 정책 항목 ### 제11조(복리후생시설) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=2d2ee93a-ccdb-4bdd-ab3c-98067781814b] End: [Document(page_content='## 제4장 복리후생시설  \n### 제11조(복리후생시설)\n① 임직원의 복리증진을 위하여 다음 각 호의 복리후생시설을 설치ㆍ운영할 수 있으며, 시행에 필요한 사항은 이사장이 별도로 정한다.\n1. 휴양시설\n2. 사내복지시설(휴게실, 식당, 매점 등)', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제4장 복리후생시설', 'Header 3': '제11조(복리후생시설)'}), Document(page_content='## 제4장 보건관리 및 복리후생시설  \n### 제11조(복리후생시설)\n① 임직원의 복리증진을 위하여 다음 각 호의 복리후생시설을 설치ㆍ운영할 수 있다.\n1. 휴양시설\n2. 체력단련시설', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제4장 보건관리 및 복리후생시설', 'Header 3': '제11조(복리후생시설)'}), Document(page_content='## 제4장 복리후생시설  \n### 제11조(복리후생시설)\n① 임직원의 복리증진을 위하여 다음 각 호의 복리후생시설을 설치ㆍ운영할 수 있으며, 시행에 필요한 사항은 이사장이 별도로 정한다.\n1. 휴양시설\n2. 사내복지시설(휴게실, 식당, 매점 등)\n② 제1항의 규정에 따라 복리후생시설을 신축ㆍ구입ㆍ임차하여 제공할 수 있으며, 예산의 범위 내에서 소요경비 등을 지급할 수 있다.\n③ 휴양시설의 이용은 『직원휴양시설 운영규칙』에 따른다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제4장 복리후생시설', 'Header 3': '제11조(복리후생시설)'}), Document(page_content='## 제4장 복리후생시설  \n### 제11조(복리후생시설)\n① 잡월드는 직원들의 삶의 질 제고를 위해 다음의 시설들을 설치, 운영할 수 있으며, 필요시 외부 위탁도 가능하다.\n1. 휴양시설: 직원들의 재충전과 심신 단련을 위한 콘도, 펜션 등의 휴양 시설\n2. 사내복지시설: 직원들이 편히 쉬고 즐길 수 있는 휴게실, 구내식당, 사내 매점 등\n② 회사는 직원들의 만족도 제고를 위해 새로운 복지시설을 신축/구입하거나 외부 시설을 임차하여 제공할 수 있다.\n③ 휴양시설 이용에 관한 구체적인 기준과 절차는 『직원휴양시설 운영규칙』에 따른다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제4장 복리후생시설', 'Header 3': '제11조(복리후생시설)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 출력:
#
# ① 직원들은 복지카드 사용 후 복리후생관을 통해 사용 내역을 신청하고, 복지점수에서 차감되도록 관리해야 한다.
# ② 복리후생관에서 자동 승인되지 않은 건에 대해서는 증빙자료와 함께 소명 신청을 해야 하며, 심사를 거쳐 승인 여부가 결정된다.
# ③ 부적격한 사용 건으로 판명될 경우 복지점수 차감 없이 직원 본인 부담으로 처리된다.
# ④ 단기계약직의 경우 복리후생관 사용이 제한될 수 있으므로, 비용 청구서와 영수증을 제출하여 수기 정산을 신청할 수 있다.
#
# <llm_comments>
# 제10조의 주요 내용을 간략하고 명확하게 요약하여 출력했습니다. 금액이나 날짜 등 구체적인 수치는 제외하고 일반화된 정책 방침만 포함시켰습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=1c6bf38d-26fd-4e9b-9fae-21fcbb0b8137] Start: 복지 정책 항목 ## 제5장 피복지급 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=1c6bf38d-26fd-4e9b-9fae-21fcbb0b8137] End: [Document(page_content='## 제5장 피복지급  \n### 제12조(피복지급)\n임직원으로서 업무상 필요한 자에 대하여는 예산범위 내에서 피복을 지급할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제5장 피복지급', 'Header 3': '제12조(피복지급)'}), Document(page_content='## 제5장 피복지급  \n### 제12조(피복지급)\n임직원으로서 업무상 필요한 자에 대하여는 예산범위 내에서 피복을 지급할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제5장 피복지급', 'Header 3': '제12조(피복지급)'}), Document(page_content='## 제5장 피복지급  \n### 제12조(피복지급)\n잡월드는 업무 특성상 제복, 작업복 등의 착용이 필요한 직원들에게 적정량의 피복을 무상 지급할 수 있다. 다만 구체적인 지급 대상과 물량은 예산 사정 등을 고려하여 결정한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제5장 피복지급', 'Header 3': '제12조(피복지급)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 제4장 복리후생시설에 규정된 내용은 다음과 같습니다:
#
# ① 임직원의 복리증진을 위하여 다음 각 호의 복리후생시설을 설치ㆍ운영할 수 있으며, 시행에 필요한 사항은 이사장이 별도로 정한다.
# 1. 휴양시설
# 2. 사내복지시설(휴게실, 식당, 매점 등)
#
# ② 제1항의 규정에 따라 복리후생시설을 신축ㆍ구입ㆍ임차하여 제공할 수 있으며, 예산의 범위 내에서 소요경비 등을 지급할 수 있다.
#
# ③ 휴양시설의 이용은 『직원휴양시설 운영규칙』에 따른다.
#
# <llm_comments>
# 이 장에서는 회사가 임직원의 복리증진을 위해 휴양시설과 사내복지시설을 설치/운영할 수 있다고 규정하고 있습니다. 또한 이러한 시설을 신축/구입/임차할 수 있으며, 예산 범위 내에서 소요경비를 지급할 수 있습니다. 휴양시설 이용 시에는 별도의 운영규칙을 따르도록 하고 있습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=90c7fddf-94ce-496e-839e-a16541fcaafc] Start: 복지 정책 항목 ### 제12조(피복지급) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=90c7fddf-94ce-496e-839e-a16541fcaafc] End: [Document(page_content='## 제3장 피복지급  \n### 제12조(피복지급)\n전 직원에게 동절기 피복을 지급한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제3장 피복지급', 'Header 3': '제12조(피복지급)'}), Document(page_content='## 제5장 피복지급  \n### 제12조(피복지급)\n임직원으로서 업무상 필요한 자에 대하여는 예산범위 내에서 피복을 지급할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제5장 피복지급', 'Header 3': '제12조(피복지급)'}), Document(page_content='## 제5장 피복지급  \n### 제12조(피복지급)\n임직원으로서 업무상 필요한 자에 대하여는 예산범위 내에서 피복을 지급할 수 있다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제5장 피복지급', 'Header 3': '제12조(피복지급)'}), Document(page_content='## 제5장 피복지급  \n### 제12조(피복지급)\n잡월드는 업무 특성상 제복, 작업복 등의 착용이 필요한 직원들에게 적정량의 피복을 무상 지급할 수 있다. 다만 구체적인 지급 대상과 물량은 예산 사정 등을 고려하여 결정한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '제5장 피복지급', 'Header 3': '제12조(피복지급)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 제8조(복지점수의 관리)에 대한 정책 내용은 다음과 같습니다:
#
# ① 회계연도 중 신규 입사, 승진, 퇴사 등 인사 발령에 따른 복지점수는 일할계산하여 관리한다.
# ② 단시간 근로자의 복지점수는 법정 근로시간에 비례하여 근무시간 만큼 차등 지급함으로써 형평성을 기한다.
# ③ 퇴직하는 직원에 대해서는 기 사용한 복지점수를 정산하여 과다 사용분에 대한 반납을 요구할 수 있다.
#
# ① 회계연도 중 신규임용 등의 신분변동이 있는 경우 변동사유가 발생한 날을 기준으로 일할계산하여 부여한다.
# ② 단시간근로자는 해당근로자의 소정근로시간을 기준으로 법정근로시간에 비례하여 지급한다.
# ③ 근로계약이 종료되는 직원에 대해서는 이미 사용한 복지점수를 일할계산하여 정산한다.
#
# <llm_comments>
# 이 정책은 복지점수 관리에 대한 세부사항을 규정하고 있습니다. 신규 입사, 승진, 퇴사 등의 인사 변동 시 복지점수를 일할 계산하여 관리하고, 단시간 근로자에게는 근무시간에 비례하여 복지점수를 차등 지급하며, 퇴직 시에는 사용한 복지점수를 정산하여 과다 사용분을 반납하도록 하고 있습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=4b1a4a05-ebcb-4901-b8b6-27b0b2aa8cad] Start: 복지 정책 항목 ## 부 칙 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=4b1a4a05-ebcb-4901-b8b6-27b0b2aa8cad] End: [Document(page_content='## 부 칙  \n### 제1조(시행일)\n이 규칙은 제정한 날부터 시행한다.  \n[별표1] 맞춤형 복지점수 기준\n| 구분 | 점수 |\n| --- | --- |\n| 자율항목 | 700,000 |\n| 특별항목 | 200,000 |  \n[별표3] 맞춤형 복지제도 사용항목', metadata={'Header 1': '복리후생 규칙', 'Header 2': '부 칙', 'Header 3': '제1조(시행일)'}), Document(page_content='## 부 칙  \n### 제1조(시행일)\n이 규칙은 2015년 6월 19일부터 시행한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '부 칙', 'Header 3': '제1조(시행일)'}), Document(page_content='## 부 칙  \n### 제1조(시행일)\n이 규칙은 제정된 날부터 즉시 시행하며, 시행 이후 변경된 내용은 변경일부터 적용한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '부 칙', 'Header 3': '제1조(시행일)'}), Document(page_content='### 제2조(적용기준일 특례)\n제5조 제2항에도 불구하고 2015년은 적용기준일을 7월 1일로 한다.  \n[별표1] 맞춤형 복지점수 기준\n| 구분 | 점수 |\n| --- | --- |\n| 자율항목 | 700,000 |\n| 특별항목 | 200,000 |  \n※ 체험형 청년인턴의 경우 매년 수립하는 채용계획에서 부여여부·수준 등 결정  \n[별표2] 휴직사유별 맞춤형 복지제도 적용 기준 (제6조제2항 관련)  \n| 구분 | 근거 | 기간 | 적용배제 또는 제한기준 |\n|-----|-----|-----|---------------------|\n| 직권휴직 | 공무상 질병휴직 | 인사규정 제44조 제1항 제1호 | 1년 이내 | 모든 항목 적용 |\n| | 질병휴직 | 인사규정 제44조 제1항 제2호 | 1년 이내 | 모든 항목 적용 |\n| | 병역휴직 | 인사규정 제44조 제1항 제3호 | 복무기간 | 적용배제 |\n| | 행방불명 | 인사규정 제44조 제1항 제4호 | 3월 이내 | 적용배제 |\n| 청원휴직 | 유학휴직 | 인사규정 제44조 제2항 제1호 | 2년 이내(2년 범위 내 연장가능) | 적용배제 |\n| | 육아휴직 | 인사규정 제44조 제2항 제2호 | 자녀 1명당 1년 이내 | 모든 항목 적용 |\n| | 간호휴직 | 인사규정 제44조 제2항 제3호 | 1년 이내 | 모든 항목 적용 |\n| | 고용휴직 | 인사규정 제44조 제2항 제4호 | 3년 이내의 채용기간 | 적용배제 |\n| | 기타휴직 | 인사규정 제44조 제2항 제5호 | 6개월 이내의 휴직기간 | 모든 항목 적용 |  \n※ 휴직 종류 및 기간은 『인사규정』 제44조(휴직 및 기간)에 의함  \n[별표3] 맞춤형 복지제도 사용항목', metadata={'Header 1': '복리후생 규칙', 'Header 2': '부 칙', 'Header 3': '제2조(적용기준일 특례)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 제11조(복리후생시설)에 규정된 내용은 다음과 같습니다:
#
# ① 임직원의 복리증진을 위하여 다음 각 호의 복리후생시설을 설치ㆍ운영할 수 있으며, 시행에 필요한 사항은 이사장이 별도로 정한다.
# 1. 휴양시설
# 2. 사내복지시설(휴게실, 식당, 매점 등)
#
# ② 제1항의 규정에 따라 복리후생시설을 신축ㆍ구입ㆍ임차하여 제공할 수 있으며, 예산의 범위 내에서 소요경비 등을 지급할 수 있다.
#
# ③ 휴양시설의 이용은 『직원휴양시설 운영규칙』에 따른다.
#
# <llm_comments>
# 이 조항은 회사가 임직원의 복리증진을 위해 휴양시설, 사내복지시설 등의 복리후생시설을 설치/운영할 수 있음을 규정하고 있습니다. 또한 이러한 시설을 신축/구입/임차할 수 있으며, 예산 범위 내에서 소요경비를 지급할 수 있습니다. 휴양시설 이용 시에는 별도의 운영규칙을 따르도록 하고 있습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=8cdba83c-4a14-4cf9-8cce-753bd24dd9f9] Start: 복지 정책 항목 ### 제1조(시행일) 에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=8cdba83c-4a14-4cf9-8cce-753bd24dd9f9] End: [Document(page_content='## 부 칙  \n### 제1조(시행일)\n이 규칙은 제정된 날부터 즉시 시행하며, 시행 이후 변경된 내용은 변경일부터 적용한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '부 칙', 'Header 3': '제1조(시행일)'}), Document(page_content='## 부 칙  \n### 제1조(시행일)\n이 규칙은 제정한 날부터 시행한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '부 칙', 'Header 3': '제1조(시행일)'}), Document(page_content='## 부 칙  \n### 제1조(시행일)\n이 규칙은 제정한 날부터 시행한다.  \n[별표1] 맞춤형 복지점수 기준\n| 구분 | 점수 |\n| --- | --- |\n| 자율항목 | 700,000 |\n| 특별항목 | 200,000 |  \n[별표3] 맞춤형 복지제도 사용항목', metadata={'Header 1': '복리후생 규칙', 'Header 2': '부 칙', 'Header 3': '제1조(시행일)'}), Document(page_content='## 부 칙  \n### 제1조(시행일)\n이 규칙은 2015년 6월 19일부터 시행한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '부 칙', 'Header 3': '제1조(시행일)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 출력:
#
# 전 직원에게 동절기 피복을 지급한다.
#
# 임직원으로서 업무상 필요한 자에 대하여는 예산범위 내에서 피복을 지급할 수 있다.
#
# 잡월드는 업무 특성상 제복, 작업복 등의 착용이 필요한 직원들에게 적정량의 피복을 무상 지급할 수 있다. 다만 구체적인 지급 대상과 물량은 예산 사정 등을 고려하여 결정한다.
#
# <llm_comments>
# 제공된 컨텍스트에서 ### 제12조(피복지급)에 해당하는 모든 정책 내용을 포함하여 출력했습니다. 중복되는 내용은 한 번만 포함시켰고, 세부 지급 대상과 물량은 예산에 따라 결정된다는 점을 명시했습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=8e62a16e-7059-4d1e-ac42-a9d76faab8ae] Start: 복지 정책 항목 ### 제2조(적용기준일 특례)에 규정된 내용을 구체적이고 상세하게 알려주세요.
# INFO:utils.TokenUsageCallbackHandler:Retriever[RUN_ID=8e62a16e-7059-4d1e-ac42-a9d76faab8ae] End: [Document(page_content='### 제2조(적용기준일 특례)\n제5조 제2항에도 불구하고 2015년은 적용기준일을 7월 1일로 한다.  \n[별표1] 맞춤형 복지점수 기준\n| 구분 | 점수 |\n| --- | --- |\n| 자율항목 | 700,000 |\n| 특별항목 | 200,000 |  \n※ 체험형 청년인턴의 경우 매년 수립하는 채용계획에서 부여여부·수준 등 결정  \n[별표2] 휴직사유별 맞춤형 복지제도 적용 기준 (제6조제2항 관련)  \n| 구분 | 근거 | 기간 | 적용배제 또는 제한기준 |\n|-----|-----|-----|---------------------|\n| 직권휴직 | 공무상 질병휴직 | 인사규정 제44조 제1항 제1호 | 1년 이내 | 모든 항목 적용 |\n| | 질병휴직 | 인사규정 제44조 제1항 제2호 | 1년 이내 | 모든 항목 적용 |\n| | 병역휴직 | 인사규정 제44조 제1항 제3호 | 복무기간 | 적용배제 |\n| | 행방불명 | 인사규정 제44조 제1항 제4호 | 3월 이내 | 적용배제 |\n| 청원휴직 | 유학휴직 | 인사규정 제44조 제2항 제1호 | 2년 이내(2년 범위 내 연장가능) | 적용배제 |\n| | 육아휴직 | 인사규정 제44조 제2항 제2호 | 자녀 1명당 1년 이내 | 모든 항목 적용 |\n| | 간호휴직 | 인사규정 제44조 제2항 제3호 | 1년 이내 | 모든 항목 적용 |\n| | 고용휴직 | 인사규정 제44조 제2항 제4호 | 3년 이내의 채용기간 | 적용배제 |\n| | 기타휴직 | 인사규정 제44조 제2항 제5호 | 6개월 이내의 휴직기간 | 모든 항목 적용 |  \n※ 휴직 종류 및 기간은 『인사규정』 제44조(휴직 및 기간)에 의함  \n[별표3] 맞춤형 복지제도 사용항목', metadata={'Header 1': '복리후생 규칙', 'Header 2': '부 칙', 'Header 3': '제2조(적용기준일 특례)'}), Document(page_content='### 제2조(적용기준일 특례)\n제5조 제2항에도 불구하고 2015년에 한해서는 종합건강검진 대상 선정의 기준일을 7월 1일로 한다.', metadata={'Header 1': '복리후생 규칙', 'Header 2': '부 칙', 'Header 3': '제2조(적용기준일 특례)'})]
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 임직원으로서 업무상 필요한 자에 대하여는 예산범위 내에서 피복을 지급할 수 있다.
#
# 잡월드는 업무 특성상 제복, 작업복 등의 착용이 필요한 직원들에게 적정량의 피복을 무상 지급할 수 있다. 다만 구체적인 지급 대상과 물량은 예산 사정 등을 고려하여 결정한다.
#
# <llm_comments>
# 제5장 피복지급 항목에는 업무상 필요한 직원에게 예산 범위 내에서 피복을 지급할 수 있다고 명시되어 있습니다. 또한 잡월드는 제복이나 작업복 착용이 필요한 직원들에게 적정량의 피복을 무상으로 지급할 수 있으며, 구체적인 지급 대상과 물량은 예산 사정을 고려하여 결정한다고 규정하고 있습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 제시된 문맥에서 복지 정책 항목 ### 제1조(시행일)에 관련된 내용은 다음과 같습니다:
#
# 이 규칙은 제정된 날부터 즉시 시행하며, 시행 이후 변경된 내용은 변경일부터 적용한다.
#
# 이 규칙은 제정한 날부터 시행한다.
#
# 이 규칙은 제정한 날부터 시행한다.
#
# 이 규칙은 2015년 6월 19일부터 시행한다.
#
# <llm_comments>
# 제시된 문맥에는 맞춤형 복지점수 기준표와 맞춤형 복지제도 사용항목 목록이 있지만, 시행일 관련 내용만 요청되었기 때문에 해당 부분은 제외했습니다.
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 제2조(적용기준일 특례)에 관한 주요 내용은 다음과 같습니다:
#
# 제5조 제2항에도 불구하고 2015년은 적용기준일을 7월 1일로 한다.
#
# [별표1] 맞춤형 복지점수 기준
# | 구분 | 점수 |
# | --- | --- |
# | 자율항목 | 700,000 |
# | 특별항목 | 200,000 |
#
# ※ 체험형 청년인턴의 경우 매년 수립하는 채용계획에서 부여여부·수준 등 결정
#
# <llm_comments>
# - 2015년에 한해 맞춤형 복지제도의 적용기준일이 7월 1일로 정해짐
# - 맞춤형 복지점수 기준표가 제시되어 있음 (자율항목 700,000점, 특별항목 200,000점)
# - 체험형 청년인턴의 경우 매년 채용계획에서 복지점수 부여 여부와 수준을 결정함
# </llm_comments>
# INFO:utils.TokenUsageCallbackHandler:LLM End Message: 출력:
#
# [별표1] 맞춤형 복지점수 기준
# | 구분 | 점수 |
# | --- | --- |
# | 자율항목 | ['blank'] |
# | 특별항목 | ['blank'] |
#
# (['blank']을 적절한 금액으로 대체해 주세요.)
#
# [별표2] 휴직사유별 맞춤형 복지제도 적용 기준 (제6조제2항 관련)
# | 구분 | 근거 | 기간 | 적용배제 또는 제한기준 |
# |-----|-----|-----|---------------------|
# | 직권휴직 | 공무상 질병휴직 | 인사규정 제44조 제1항 제1호 | 1년 이내 | 모든 항목 적용 |
# | | 질병휴직 | 인사규정 제44조 제1항 제2호 | 1년 이내 | 모든 항목 적용 |
# | | 병역휴직 | 인사규정 제44조 제1항 제3호 | 복무기간 | 적용배제 |
# | | 행방불명 | 인사규정 제44조 제1항 제4호 | 3월 이내 | 적용배제 |
# | 청원휴직 | 유학휴직 | 인사규정 제44조 제2항 제1호 | 2년 이내(2년 범위 내 연장가능) | 적용배제 |
# | | 육아휴직 | 인사규정 제44조 제2항 제2호 | 자녀 1명당 1년 이내 | 모든 항목 적용 |
# | | 간호휴직 | 인사규정 제44조 제2항 제3호 | 1년 이내 | 모든 항목 적용 |
# | | 고용휴직 | 인사규정 제44조 제2항 제4호 | 3년 이내의 채용기간 | 적용배제 |
# | | 기타휴직 | 인사규정 제44조 제2항 제5호 | 6개월 이내의 휴직기간 | 모든 항목 적용 |
#
# [별표3] 맞춤형 복지제도 사용항목
#
# <llm_comments>
# 위 출력은 부칙에 규정된 맞춤형 복지점수 기준표, 휴직사유별 맞춤형 복지제도 적용 기준표, 맞춤형 복지제도 사용항목을 포함하고 있습니다. 금액 부분은 ['blank']로 표시하고 적절한 금액으로 대체해야 한다는 설명을 추가했습니다.
# </llm_comments>
# INFO:utils.DocumentManager:Normalized document is saved to output/한국잡월드_복리후생_표준파일_리랭커미사용.md
# Successful Requests: 21
# Tokens Used: 28605
# 	Prompt Tokens: 19728
# 	Completion Tokens: 8877
# Total Cost (USD): $0.19233900000000004
